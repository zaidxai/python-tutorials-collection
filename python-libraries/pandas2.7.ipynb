# %%
names = ['United States', 'Australia', 'Japan', 'India', 'Russia', 'Morocco', 'Egypt']
dr =  [True, False, False, False, True, True, True]
cpc = [809, 731, 588, 18, 200, 70, 45]

# %%
import pandas as pd

# %%
my_dict={'country_names':names,'drives_right':dr,'cars_per_capta':cpc}

# %%
cars=pd.DataFrame(my_dict)

# %%
print(cars)
# Out:
#    country_names  drives_right  cars_per_capta
# 0  United States          True             809
# 1      Australia         False             731
# 2          Japan         False             588
# 3          India         False              18
# 4         Russia          True             200
# 5        Morocco          True              70
# 6          Egypt          True              45
